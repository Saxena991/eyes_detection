# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from skimage.io import imread,imshow
import cv2
# %matplotlib inline

# %%
img=cv2.imread("C:\my_first_project/test_img/man.jpg")
imshow(img)

# %%
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
rgb.shape
# Out:
# (408, 612, 3)

# %%
print(imshow(rgb))
# Out:
# AxesImage(32.605,27.8;388.595x245.666)

# %%
plt.imshow(rgb, cmap='gray')

# %%
eye_cascade = cv2.CascadeClassifier(".\opencv\haarcascade_eye.xml")
eyes = eye_cascade.detectMultiScale(rgb, 1.3, 5)
eyes
# Out:
# array([[317, 131,  46,  46],
#        [256, 130,  48,  48]])

# %%
(x,y,w,h) = eyes[0]
(x,y,w,h) = eyes[1]
x,y,w,h
# Out:
# (256, 130, 48, 48)
